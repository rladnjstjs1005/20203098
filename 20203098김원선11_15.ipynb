# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 코랩 구글 드라이브 마운트

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# OpenCV를 사용하기 위해 cv2를 임포트합니다.
#
# Google Colab 환경에서 이미지를 시각화하기 위해 cv2_imshow를 임포트합니다.

# %%
img ='/content/drive/MyDrive/pig.jpg'
image = cv2.imread(img)

# %% [markdown]
# img에 원하는 사진 저장하고 image에 읽은 사진을 저장합니다.

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=238x180>

# %% [markdown]
# 원하는 사진을 출력합니다.

# %%
blur = cv2.GaussianBlur(image,ksize=(3,3),sigmaX=0)
ret,thresh1=cv2.threshold(blur,127,255,cv2.THRESH_BINARY)
edged = cv2.Canny(blur,10,250)
cv2_imshow(edged)
# Out:
# <PIL.Image.Image image mode=L size=238x180>

# %% [markdown]
# 원하는 사진의 테두리만 출력합니다.
